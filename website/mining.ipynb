# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
from flask import Flask, request, url_for, redirect, render_template
import sqlite3
import sqlalchemy

plt.style.use('fivethirtyeight')

engine = sqlalchemy.create_engine('sqlite:///database.db')

pd.read_sql('user', engine)
# Out:
#    id                    email   firstname  lastname  \
# 0   1      yakupicer@gmail.com       Yakup      İçer
# 1   2  esmaaa.mercan@gmail.com        Esma    Mercan
# 2   3          admin@gmail.com        afsd       faw
# 3   4   dytserapicer@gmail.com  adfgfdadgf  sdgfdadf
# 4   5            asd@gmail.com       rtert    ertert
# 5   6          qdwdqw@ahah.com      jpojpo    pokopk
#
#                                             password
# 0  sha256$sk7MbGofdJNQq3y6$9db2bc9570c2887f224a0f...
# 1  sha256$wmte1mx5Ie6fqTG2$2f9d22d1d0ad4692f620f5...
# 2  sha256$AmQI09eEoWQHWzW4$fc76c3ab5e49e7981244f6...
# 3  sha256$i9hHsLkv9cZF42uz$3a17cf03553b4df8e43975...
# 4  sha256$mrlWYvTQmCwjOg24$c6ff3fe1ce1acdcfeed98e...
# 5  sha256$tbL8gXuBnTeKHAKE$0861035e196944bf182f09...
